# %% [markdown]
# # <span style="color:red">Your Ultimate guide for working with data from APIs</span>

# %% [markdown]
# <span style="color:blue">**APIs (Application Programming Interface)** is meant to share data between two application. APIs are provided by the organization itself. We can access these data from APIs using our private keys or some APIs don't even need any key and perform some analysis to fulfill our desired need.</span>

# %%
import pandas as pd
import requests

# %%
response = requests.get("http://universities.hipolabs.com/search?country=United+States")

# %%
df = pd.DataFrame(response.json())[['name', 'alpha_two_code', 'state-province', 'domains', 'country', 'web_pages']]

# %%
df
# Out:
#                                        name alpha_two_code state-province
# 0                       Marywood University             US           None  \
# 1                     Lindenwood University             US           None
# 2                       Sullivan University             US           None
# 3     Florida State College at Jacksonville             US           None
# 4                         Xavier University             US           None
# ...                                     ...            ...            ...
# 2279           Detroit School of Technology             US           None
# 2280                  North Central College             US           None
# 2281      The University of Montana Western             US           None
# 2282         Queens University of Charlotte             US           None
# 2283            Lincoln Memorial University             US           None
#
#                         domains        country
# 0                [marywood.edu]  United States  \
# 1              [lindenwood.edu]  United States
# 2                [sullivan.edu]  United States
# 3                    [fscj.edu]  United States
# 4                  [xavier.edu]  United States
# ...                         ...            ...
# 2279                 [dsdt.edu]  United States
# 2280  [northcentralcollege.edu]  United States
# 2281            [umwestern.edu]  United States
# 2282               [queens.edu]  United States
# 2283               [lmunet.edu]  United States
#
#                                    web_pages
# 0                  [http://www.marywood.edu]
# 1               [http://www.lindenwood.edu/]
# 2                    [https://sullivan.edu/]
# 3                    [https://www.fscj.edu/]
# 4                  [https://www.xavier.edu/]
# ...                                      ...
# 2279                     [https://dsdt.edu/]
# 2280  [https://www.northcentralcollege.edu/]
# 2281            [https://www.umwestern.edu/]
# 2282               [https://www.queens.edu/]
# 2283               [https://www.lmunet.edu/]
#
# [2284 rows x 6 columns]

# %% [markdown]
# <span style="color:blue">As you can see I created a DF from the data coming from API. And further I can perform all the operation I can perform Pandas DF. You can also convert into a .csv file like this.</span>

# %%
df.to_csv('university.csv')

# %%
df.sample(13)
# Out:
#                                                name alpha_two_code
# 2198                       Arkansas Baptist College             US  \
# 14          University of Pittsburgh Medical Center             US
# 2009                              Clarendon College             US
# 57                                Tiffin University             US
# 1675   Mesabi Range Community and Technical College             US
# 1813                       Nassau Community College             US
# 147                Antioch University - Los Angeles             US
# 738                                  Pomona College             US
# 1464         Georgia Northwestern Technical College             US
# 945              University of Advancing Technology             US
# 1106             University of Texas Medical Branch             US
# 1950  Harrisburg Area Community College-​Harrisburg             US
# 28                   Western New England University             US
#
#      state-province                 domains        country
# 2198           None   [arkansasbaptist.edu]  United States  \
# 14     Pennsylvania    [upmc.edu, upmc.com]  United States
# 2009           None  [clarendoncollege.edu]  United States
# 57             None            [tiffin.edu]  United States
# 1675           None       [mesabirange.edu]  United States
# 1813           None               [ncc.edu]  United States
# 147            None         [antiochla.edu]  United States
# 738            None            [pomona.edu]  United States
# 1464           None              [gntc.edu]  United States
# 945            None               [uat.edu]  United States
# 1106           None              [utmb.edu]  United States
# 1950           None              [hacc.edu]  United States
# 28             None               [wne.edu]  United States
#
#                                web_pages
# 2198  [https://www.arkansasbaptist.edu/]
# 14               [https://www.upmc.com/]
# 2009   [http://www.clarendoncollege.edu]
# 57              [http://www.tiffin.edu/]
# 1675        [http://www.mesabirange.edu]
# 1813               [http://www.ncc.edu/]
# 147          [http://www.antiochla.edu/]
# 738             [http://www.pomona.edu/]
# 1464               [http://www.gntc.edu]
# 945                [http://www.uat.edu/]
# 1106              [http://www.utmb.edu/]
# 1950               [http://www.hacc.edu]
# 28                [http://www1.wne.edu/]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2284 entries, 0 to 2283
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2284 non-null   object
#  1   alpha_two_code  2284 non-null   object
#  2   state-province  84 non-null     object
#  3   domains         2284 non-null   object
#  4   country         2284 non-null   object
#  5   web_pages       2284 non-null   object
# dtypes: object(6)
# memory usage: 107.2+ KB

# %%
df.isnull()
# Out:
#        name  alpha_two_code  state-province  domains  country  web_pages
# 0     False           False            True    False    False      False
# 1     False           False            True    False    False      False
# 2     False           False            True    False    False      False
# 3     False           False            True    False    False      False
# 4     False           False            True    False    False      False
# ...     ...             ...             ...      ...      ...        ...
# 2279  False           False            True    False    False      False
# 2280  False           False            True    False    False      False
# 2281  False           False            True    False    False      False
# 2282  False           False            True    False    False      False
# 2283  False           False            True    False    False      False
#
# [2284 rows x 6 columns]

# %% [markdown]
# # Let's take it one more step ahead

# %%
countries = ['India', 'United+States', 'Canada', 'United+Kingdom', 'Saudi+Arabia', 'Japan', 'China', 'Pakistan', 'Portugal', 'France', 'Germany', 'Australia', 'Spain', 'Iran', 'Iraq', 'Brazil']

# %%
uni_df = pd.DataFrame()

# %%
for country_name in countries:
    response2 = requests.get('http://universities.hipolabs.com/search?country={}'.format(country_name))
    temp_df = pd.DataFrame(response2.json())[['name', 'alpha_two_code', 'state-province', 'domains', 'country', 'web_pages']]
    uni_df = pd.concat([uni_df, temp_df])

# %%
uni_df
# Out:
#                                             name alpha_two_code
# 0     University of Petroleum and Energy Studies             IN  \
# 1      DAV Institute of Engineering & Technology             IN
# 2                 Lovely Professional University             IN
# 3                             Somaiya Vidyavihar             IN
# 4                            NorthCap University             IN
# ..                                           ...            ...
# 172                                      UNINOVE             BR
# 173         Polytechnic University of Pernambuco             BR
# 174                   Cruzeiro do Sul University             BR
# 175  Universidade Virtual do Estado de São Paulo             BR
# 176     Universidade Estadual do Norte do Parana             BR
#
#     state-province                                domains country
# 0         Dehradun                           [upes.ac.in]   India  \
# 1           Punjab                        [davietjal.org]   India
# 2           Punjab                               [lpu.in]   India
# 3             None                          [somaiya.edu]   India
# 4          Haryana                         [ncuindia.edu]   India
# ..             ...                                    ...     ...
# 172           None              [uninove.br, uni9.edu.br]  Brazil
# 173           None  [upe.poli.br, ecomp.poli.br, poli.br]  Brazil
# 174           None           [aluno.cruzeirodosul.edu.br]  Brazil
# 175           None                           [univesp.br]  Brazil
# 176           None                          [uenp.edu.br]  Brazil
#
#                           web_pages
# 0         [https://www.upes.ac.in/]
# 1       [http://www.davietjal.org/]
# 2              [http://www.lpu.in/]
# 3            [https://somaiya.edu/]
# 4        [http://www.ncuindia.edu/]
# ..                              ...
# 172            [https://uninove.br]
# 173           [https://upe.poli.br]
# 174  [https://cruzeirodosul.edu.br]
# 175           [https://univesp.br/]
# 176          [https://uenp.edu.br/]
#
# [5435 rows x 6 columns]

# %%
uni_df['country'].is_unique
# Out:
# False

# %%
uni_df['country'].unique()
# Out:
# array(['India', 'United States', 'Canada', 'United Kingdom',
#        'Saudi Arabia', 'Japan', 'China', 'Pakistan', 'Portugal', 'France',
#        'Germany', 'Australia', 'Spain', 'Iran', 'Iraq', 'Brazil'],
#       dtype=object)

# %% [markdown]
# <span style="color:blue"> It's showing we have got data from all these countries. These way you can keep traversing the API and getting any required amount of data. But make sure the data you're asking for should be availabel on API and it will allow access you to that data. </span>

# %%
uni_df.to_csv('uni_data.csv')
