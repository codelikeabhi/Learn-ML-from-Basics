# %% [markdown]
# # <span style="color:red">Ultimate Guide to working with JSON and SQL</span>

# %% [markdown]
# ## Working with local JSON file

# %%
import pandas as pd

# %%
pd.read_json('recipe.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# <span style="color:blue">Now the above **JSON file** is converted into a **DataFrame** and you can perform all the operations we performed in last notebook / or all the Pandas functionalities. </span>

# %% [markdown]
# ## Working with JSON using URL

# %%
json_df = pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')

# %%
json_df
# Out:
#                              provider
# AED  https://www.exchangerate-api.com  \
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6
# AED  https://www.exchangerate-api.com/docs/free  \
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date
# AED  https://www.exchangerate-api.com/terms  INR 2024-01-19  \
# AFN  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ALL  https://www.exchangerate-api.com/terms  INR 2024-01-19
# AMD  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ANG  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2024-01-19
# YER  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ZAR  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ZMW  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ZWL  https://www.exchangerate-api.com/terms  INR 2024-01-19
#
#      time_last_updated     rates
# AED         1705622402    0.0442
# AFN         1705622402    0.8770
# ALL         1705622402    1.1600
# AMD         1705622402    4.8700
# ANG         1705622402    0.0215
# ..                 ...       ...
# XPF         1705622402    1.3200
# YER         1705622402    2.9700
# ZAR         1705622402    0.2280
# ZMW         1705622402    0.3170
# ZWL         1705622402  105.4800
#
# [162 rows x 7 columns]

# %%
json_df.sample(10)
# Out:
#                              provider
# XAF  https://www.exchangerate-api.com  \
# TZS  https://www.exchangerate-api.com
# SEK  https://www.exchangerate-api.com
# KYD  https://www.exchangerate-api.com
# CNY  https://www.exchangerate-api.com
# NAD  https://www.exchangerate-api.com
# RUB  https://www.exchangerate-api.com
# GHS  https://www.exchangerate-api.com
# ARS  https://www.exchangerate-api.com
# ETB  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6
# XAF  https://www.exchangerate-api.com/docs/free  \
# TZS  https://www.exchangerate-api.com/docs/free
# SEK  https://www.exchangerate-api.com/docs/free
# KYD  https://www.exchangerate-api.com/docs/free
# CNY  https://www.exchangerate-api.com/docs/free
# NAD  https://www.exchangerate-api.com/docs/free
# RUB  https://www.exchangerate-api.com/docs/free
# GHS  https://www.exchangerate-api.com/docs/free
# ARS  https://www.exchangerate-api.com/docs/free
# ETB  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date
# XAF  https://www.exchangerate-api.com/terms  INR 2024-01-19  \
# TZS  https://www.exchangerate-api.com/terms  INR 2024-01-19
# SEK  https://www.exchangerate-api.com/terms  INR 2024-01-19
# KYD  https://www.exchangerate-api.com/terms  INR 2024-01-19
# CNY  https://www.exchangerate-api.com/terms  INR 2024-01-19
# NAD  https://www.exchangerate-api.com/terms  INR 2024-01-19
# RUB  https://www.exchangerate-api.com/terms  INR 2024-01-19
# GHS  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ARS  https://www.exchangerate-api.com/terms  INR 2024-01-19
# ETB  https://www.exchangerate-api.com/terms  INR 2024-01-19
#
#      time_last_updated    rates
# XAF         1705622402   7.2600
# TZS         1705622402  30.3400
# SEK         1705622402   0.1260
# KYD         1705622402   0.0100
# CNY         1705622402   0.0866
# NAD         1705622402   0.2280
# RUB         1705622402   1.0700
# GHS         1705622402   0.1460
# ARS         1705622402   9.8500
# ETB         1705622402   0.6800

# %%
json_df.iloc[1:4]
# Out:
#                              provider
# AFN  https://www.exchangerate-api.com  \
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6
# AFN  https://www.exchangerate-api.com/docs/free  \
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date
# AFN  https://www.exchangerate-api.com/terms  INR 2024-01-19  \
# ALL  https://www.exchangerate-api.com/terms  INR 2024-01-19
# AMD  https://www.exchangerate-api.com/terms  INR 2024-01-19
#
#      time_last_updated  rates
# AFN         1705622402  0.877
# ALL         1705622402  1.160
# AMD         1705622402  4.870

# %% [markdown]
# <span style="color:blue">You can also load data into **DataFrame** using an URL like this. But make sure that your URL must be returning a .json file and not any other file. And you can perform all the operations we performed in last notebook / or all the Pandas functionalities.</span>

# %% [markdown]
# ## Working with SQL files

# %%
# !pip install pymysql

#must exclamation is a must as it is a terminal command
# Out:
# Requirement already satisfied: pymysql in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (1.1.0)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymysql

# %%
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='password',
    database='random_data',
    charset='utf8mb4',
    cursorclass=pymysql.cursors.DictCursor
)

# %%
df = pd.read_sql_query("SELECT * FROM rand_table",conn)
# Out:
# C:\Users\Abhishek\AppData\Local\Temp\ipykernel_24200\3490384253.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM rand_table",conn)

# %%
df.head()
# Out:
#    username  passkey
# 0  username  passkey
# 1  username  passkey
# 2  username  passkey
# 3  username  passkey

# %% [markdown]
# <span style="color:blue"> This way you can convert your SQL database into a DataFrame and perform operations provided by Pandas. (Above given data is a dummy dataset given to make you understand the concept) </span>
